# %%
from firecrawl import Firecrawl

firecrawl = Firecrawl(api_key="fc-ec73eb1678be49b8a4d19ad696818c74")
results = firecrawl.search(query="cough & cold related blogs from parentune", limit=3)

# %%
results
# Out:
# SearchData(web=[SearchResultWeb(url='https://www.parentune.com/parent-blog/fighting-cold-and-flu/389', title='Cold and Flu Causes, Symptoms, Treatment Home Remedies ...', description='This blog is helpful for parents to know the symptoms, home remedies of cold and flu. Read more to understand the difference between these ...', category=None), SearchResultWeb(url='https://www.parentune.com/parent-blog/what-food-and-home-remedies-for-cold-cough/2331', title='What Food to Choose During Cold & Cough & Home Remedies?', description='Look Cough And Cold Symptoms in Your Child · A runny Nose · Sneezing · Vomiting Tendency · Eventually the loss of appetite · Heavy voice · Chest ...', category=None), SearchResultWeb(url='https://www.parentune.com/parent-blog/use-honey-to-treat-cough-cold-in-your-child/3592', title='How To Use Honey To Treat Cough & Cold In Your Child - Parentune', description='Just give your child one teaspoon of pure honey once or twice a day. It coats the throat and reduces 
# ...

# %%
dir(results)
# Out:
# ['__abstractmethods__',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__class_vars__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__fields__',
#  '__fields_set__',
#  '__format__',
#  '__ge__',
#  '__get_pydantic_core_schema__',
#  '__get_pydantic_json_schema__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__pretty__',
#  '__private_attributes__',
#  '__pydantic_complete__',
#  '__pydantic_computed_fields__',
#  '__pydantic_core_schema__',
#  '__pydantic_custom_init__',
#  '__pydantic_decorators__',
#  '__pydantic_extra__',
#  '__pydantic_fields__',
#  '__pydantic_fields_set__',
#  '__pydantic_generic_metadata__',
#  '__pydantic_init_subclass__',
#  '__pydantic_on_complete__',
#  '__pydantic_parent_namespace__',
# ...

# %%
results.web[0].__dict__
# Out:
# {'url': 'https://www.parentune.com/parent-blog/fighting-cold-and-flu/389',
#  'title': 'Cold and Flu Causes, Symptoms, Treatment Home Remedies ...',
#  'description': 'This blog is helpful for parents to know the symptoms, home remedies of cold and flu. Read more to understand the difference between these ...',
#  'category': None}

# %%
for i in results.web:
    print(i.url)
# Out:
# https://www.parentune.com/parent-blog/fighting-cold-and-flu/389
# https://www.parentune.com/parent-blog/what-food-and-home-remedies-for-cold-cough/2331
# https://www.parentune.com/parent-blog/use-honey-to-treat-cough-cold-in-your-child/3592

# %%
for title in results.web:
    print(title.title)
# Out:
# Cold and Flu Causes, Symptoms, Treatment Home Remedies ...
# What Food to Choose During Cold & Cough & Home Remedies?
# How To Use Honey To Treat Cough & Cold In Your Child - Parentune

# %%
for desc in results.web:
    print(desc.description)
# Out:
# This blog is helpful for parents to know the symptoms, home remedies of cold and flu. Read more to understand the difference between these ...
# Look Cough And Cold Symptoms in Your Child · A runny Nose · Sneezing · Vomiting Tendency · Eventually the loss of appetite · Heavy voice · Chest ...
# Just give your child one teaspoon of pure honey once or twice a day. It coats the throat and reduces dryness and coughing. Make sure to use pure ...

# %% [markdown]
# # Scrapping Tool

# %%
from firecrawl import Firecrawl

firecrawl = Firecrawl(api_key="fc-ec73eb1678be49b8a4d19ad696818c74")

result = firecrawl.scrape(
    url='https://www.facebook.com',
    formats=['markdown']
)

print(result)
# Out:
# ---------------------------------------------------------------------------
# WebsiteNotSupportedError                  Traceback (most recent call last)
# Cell In[29], line 5
#       1 from firecrawl import Firecrawl
#       3 firecrawl = Firecrawl(api_key="fc-ec73eb1678be49b8a4d19ad696818c74")
# ----> 5 result = firecrawl.scrape(
#       6     url='https://www.facebook.com',
#       7     formats=['markdown']
#       8 )
#      10 print(result)
#
# File ~/miniconda3/envs/Crewai/lib/python3.12/site-packages/firecrawl/v2/client.py:177, in FirecrawlClient.scrape(self, url, formats, headers, include_tags, exclude_tags, only_main_content, timeout, wait_for, mobile, parsers, actions, location, skip_tls_verification, remove_base64_images, fast_mode, use_mock, block_ads, proxy, max_age, store_in_cache, integration)
#     127 """
#     128 Scrape a single URL and return the document.
#     129 Args:
#    (...)    151     Document
#     152 """
#     153 options = ScrapeOptions(
# ...

# %%
result.__dict__
# Out:
# {'markdown': "Age GroupsPregnancy0-1 years1-3 years3-7 years7-11 years11-16 yearsAdoptionConceivingMy Interests\n\n# Parentune is the only Parent focused specialized program\n\n## Trusted by 5mn Parents. Most Loved Parenting APP Developed with inputs from 500+Doctors & Experts.\n\n[![apple-logo](https://www.parentune.com/_next/image?url=%2FIcons%2FappleLogo.png&w=96&q=75)Get it onApp Store](https://apps.apple.com/in/app/parentune/id6448415937) [![play-store-log](https://www.parentune.com/_next/image?url=https%3A%2F%2Fimg1.parentune.com%2Fhome_assets%2Fplus%2Fplay-store.webp&w=96&q=75)Get it onPlay Store](https://play.google.com/store/apps/details?id=com.parentune.app)\n\n[![We are a community of](https://img1.parentune.com/images/homepage/header/banner-00.png)**We are a community of** \\\\\n\\\\\n**Parents** **5Mn**](https://www.parentune.com/parent-talk) [![](https://img1.parentune.com/images/homepage/header/Dr%20rakesh%20tiwari-13.jpg)\\\\\n\\\\\n**Doctors** **500+**](https://www.p
# ...

# %%
from crewai_tools import ScrapeWebsiteTool

# To enable scrapping any website it finds during it's execution
tool = ScrapeWebsiteTool()

# Initialize the tool with the website URL, 
# so the agent can only scrap the content of the specified website
tool = ScrapeWebsiteTool(website_url='https://www.mushroomapp.xyz')

# Extract the text from the site
text = tool.run()
print(text)
# Out:
# Using Tool: Read website content
# The following text is scraped website content:
# 🍄 AI Mushroom Mentor - Meghalaya's Mycology Guide
# > Mushroom.ai initialized in Meghalaya 🍄
# 🍄 AI Mushroom Mentor
# 📍 Specialized for Meghalaya
# Your intelligent companion for exploring Meghalaya's rich mycological diversity. Empowering farmers and enthusiasts with AI-powered mushroom identification and disease detection.
# 🌿 Built for Northeast India
# 🏔️
# Meghalaya native species database
# 👨‍🌾
# Farmer-focused disease detection
# 🌧️
# Monsoon season guidance
# 🗣️
# Local language support
# 🔍
# AI Disease Detection
# Advanced AI instantly identifies mushroom diseases and provides treatment recommendations for farmers and cultivators
# 🏔️
# Meghalaya Species Guide
# Comprehensive database of indigenous mushrooms found in Khasi Hills, Garo Hills, and Jaintia Hills regions
# 👨‍🌾
# Farmer Support
# Specialized tools for mushroom cultivation, pest management, and yield optimization for local farmers
# ...

# %%
print(result.markdown)
# Out:
# Age GroupsPregnancy0-1 years1-3 years3-7 years7-11 years11-16 yearsAdoptionConceivingMy Interests
#
# # Parentune is the only Parent focused specialized program
#
# ## Trusted by 5mn Parents. Most Loved Parenting APP Developed with inputs from 500+Doctors & Experts.
#
# [![apple-logo](https://www.parentune.com/_next/image?url=%2FIcons%2FappleLogo.png&w=96&q=75)Get it onApp Store](https://apps.apple.com/in/app/parentune/id6448415937) [![play-store-log](https://www.parentune.com/_next/image?url=https%3A%2F%2Fimg1.parentune.com%2Fhome_assets%2Fplus%2Fplay-store.webp&w=96&q=75)Get it onPlay Store](https://play.google.com/store/apps/details?id=com.parentune.app)
#
# [![We are a community of](https://img1.parentune.com/images/homepage/header/banner-00.png)**We are a community of** \\
# \\
# **Parents** **5Mn**](https://www.parentune.com/parent-talk) [![](https://img1.parentune.com/images/homepage/header/Dr%20rakesh%20tiwari-13.jpg)\\
# \\
# ...
